# %%
import sys
# !{sys.executable} -m pip install datasets
from datasets import load_dataset
import pandas as pd

# Load dataset
dataset = load_dataset("SetFit/enron_spam")

# Convert to pandas
df = pd.DataFrame(dataset['train'])

# Rename columns (cleaner)
Data = df.rename(columns={
    "text": "email",
    "label": "spam"
})

# Convert labels: 1 = spam, 0 = ham
print(df.head())
print(Data['spam'].value_counts())
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: datasets in c:\users\khais\appdata\roaming\python\python313\site-packages (4.8.4)
# Requirement already satisfied: filelock in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (2.3.5)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (0.4.1)
# Requirement already satisfied: pandas in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (3.0.0)
# Requirement already satisfied: requests>=2.32.2 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (0.36.0)
# Requirement already satisfied: packaging in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\khais\appdata\roaming\python\python313\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\khais\appdata\roaming\python\python313\site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.5)
# Requirement already satisfied: anyio in c:\users\khais\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets) (4.10.0)
# Requirement already satisfied: certifi in c:\users\khais\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\khais\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in c:\users\khais\appdata\roaming\python\python313\site-packages (from httpx<1.0.0->datasets) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\khais\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\khais\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\khais\appdata\roaming\python\python313\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\khais\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khais\appdata\roaming\python\python313\site-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: colorama in c:\users\khais\appdata\roaming\python\python313\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\khais\appdata\roaming\python\python313\site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\khais\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\khais\appdata\roaming\python\python313\site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\khais\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Repo card metadata block was not found. Setting CardData to empty.
#    message_id                                               text  label  \
# 0       33214  any software just for 15 $ - 99 $ understandin...      1
# 1       11929  perspective on ferc regulatory action client c...      0
# 2       19784  wanted to try ci 4 lis but thought it was way ...      1
# 3        2209  enron / hpl actuals for december 11 , 2000 tec...      0
# 4       15880  looking for cheap high - quality software ? ro...      1
#
#   label_text                                            subject  \
# 0       spam                  any software just for 15 $ - 99 $
# 1        ham  perspective on ferc regulatory action client c...
# 2       spam  wanted to try ci 4 lis but thought it was way ...
# 3        ham         enron / hpl actuals for december 11 , 2000
# 4       spam  looking for cheap high - quality software ? ro...
#
#                                              message       date
# 0  understanding oem software\nlead me not into t... 2005-06-18
# 1  19 th , 2 : 00 pm edt\nperspective on ferc reg... 2001-06-19
# 2  viagra at $ 1 . 12 per dose\nready to boost yo... 2004-09-11
# 3  teco tap 30 . 000 / enron ; 120 . 000 / hpl ga... 2000-12-12
# 4  water past also , burn , course . gave country... 2005-02-13
# spam
# 1    16163
# 0    15553
# Name: count, dtype: int64

# %%
print(df.tail())

print(df.describe())
# Out:
#        message_id                                               text  label  \
# 31711       14628  credit netco start up plan louise ,\nattached ...      0
# 31712       16049  everything you are looking for hello , visit o...      1
# 31713       18024  start date : 2 / 5 / 02 ; hourahead hour : 18 ...      0
# 31714        1639  corhshucker daren - - - -\nthe invoices are be...      0
# 31715        7296  re : prosym license hi karolina ,\nthe last wo...      0
#
#       label_text                                          subject  \
# 31711        ham                       credit netco start up plan
# 31712       spam                   everything you are looking for
# 31713        ham  start date : 2 / 5 / 02 ; hourahead hour : 18 ;
# 31714        ham                                      corhshucker
# 31715        ham                              re : prosym license
#
#                                                  message       date
# 31711  louise ,\nattached is the electronic version o... 2002-01-07
# 31712  hello , visit our amazing\nonline shop !\nnows... 2005-03-26
# 31713  start date : 2 / 5 / 02 ; hourahead hour : 18 ... 2002-02-05
# 31714  daren - - - -\nthe invoices are being paid by ... 2000-09-19
# 31715  hi karolina ,\nthe last word i got was that gr... 2000-10-18
#          message_id         label                        date
# count  31716.000000  31716.000000                       31716
# mean   16854.187539      0.509617  2003-01-15 08:32:00.544835
# min        0.000000      0.000000         1999-12-10 00:00:00
# 25%     8429.750000      0.000000         2001-03-08 00:00:00
# 50%    16850.500000      1.000000         2002-05-28 00:00:00
# 75%    25295.250000      1.000000         2005-02-03 00:00:00
# max    33715.000000      1.000000         2005-09-06 00:00:00
# std     9734.616392      0.499915                         NaN
